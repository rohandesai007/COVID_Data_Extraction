# %%
import pandas as pd
import requests

url = "https://www.worldometers.info/coronavirus/country/us/"
r = requests.get(url)
df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list
df = df_list[0]
df.head()
# Out:
#      #    USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0  NaN   USA Total     7600846       NaN     214277.0        NaN
# 1  1.0  California      829744       NaN      16119.0        NaN
# 2  2.0       Texas      802180       NaN      16480.0        NaN
# 3  3.0     Florida      714591       NaN      14640.0        NaN
# 4  4.0    New York      498034       NaN      33290.0        NaN
#
#    TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 0       4818509.0    2568060.0           22963.0          647.0  110526283.0
# 1        425001.0     388624.0           21000.0          408.0   14998888.0
# 2        695684.0      90016.0           27665.0          568.0    7020828.0
# 3        354291.0     345660.0           33271.0          682.0    5383648.0
# 4        397523.0      67221.0           25601.0         1711.0   11110291.0
#
#    Tests/ 1M pop  Population                        Source    Projections
# 0       333914.0         NaN                           NaN            NaN
# 1       379601.0  39512223.0          [view by county] [1]  [projections]
# 2       242132.0  28995881.0      [view by county] [1] [2]  [projections]
# 3       250662.0  21477737.0  [view by county] [1] [2] [3]  [projections]
# 4       571119.0  19453561.0  [view by county] [1] [2] [3]  [projections]

# %%
del df['Source']
del df['Projections']

# %%
df
# Out:
#        #               USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0    NaN              USA Total     7600846       NaN     214277.0        NaN
# 1    1.0             California      829744       NaN      16119.0        NaN
# 2    2.0                  Texas      802180       NaN      16480.0        NaN
# 3    3.0                Florida      714591       NaN      14640.0        NaN
# 4    4.0               New York      498034       NaN      33290.0        NaN
# ..   ...                    ...         ...       ...          ...        ...
# 59  59.0          Navajo Nation       10404       NaN        558.0        NaN
# 60  60.0    Grand Princess Ship         103       NaN          3.0        NaN
# 61  61.0      Wuhan Repatriated           3       NaN          NaN        NaN
# 62  62.0  Diamond Princess Ship          46       NaN          NaN        NaN
# 63   NaN                 Total:     7600846       NaN     214277.0        NaN
#
#     TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 0        4818509.0    2568060.0           22963.0          647.0  110526283.0
# 1         425001.0     388624.0           21000.0          408.0   14998888.0
# 2         695684.0      90016.0           27665.0          568.0    7020828.0
# 3         354291.0     345660.0           33271.0          682.0    5383648.0
# 4         397523.0      67221.0           25601.0         1711.0   11110291.0
# ..             ...          ...               ...            ...          ...
# 59             NaN          NaN               NaN            NaN     102753.0
# 60             NaN        100.0               NaN            NaN          NaN
# 61             NaN          3.0               NaN            NaN          3.0
# 62             NaN         46.0               NaN            NaN         46.0
# 63       4818509.0    2568060.0           22963.0          647.0  110526283.0
#
#     Tests/ 1M pop  Population
# 0        333914.0         NaN
# 1        379601.0  39512223.0
# 2        242132.0  28995881.0
# 3        250662.0  21477737.0
# 4        571119.0  19453561.0
# ..            ...         ...
# 59            NaN         NaN
# 60            NaN         NaN
# 61            NaN         NaN
# 62            NaN         NaN
# 63       333914.0         NaN
#
# [64 rows x 13 columns]

# %%
del df['#']

# %%
df.head(50)
# Out:
#                 USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0              USA Total     7600846       NaN     214277.0        NaN
# 1             California      829744       NaN      16119.0        NaN
# 2                  Texas      802180       NaN      16480.0        NaN
# 3                Florida      714591       NaN      14640.0        NaN
# 4               New York      498034       NaN      33290.0        NaN
# 5                Georgia      322078       NaN       7134.0        NaN
# 6               Illinois      302827       NaN       9023.0        NaN
# 7                Arizona      220399       NaN       5705.0        NaN
# 8         North Carolina      216886       NaN       3629.0        NaN
# 9             New Jersey      211217       NaN      16254.0        NaN
# 10             Tennessee      199595       NaN       2560.0        NaN
# 11             Louisiana      167401       NaN       5545.0        NaN
# 12          Pennsylvania      166270       NaN       8278.0        NaN
# 13               Alabama      158380       NaN       2558.0        NaN
# 14                  Ohio      158017       NaN       4930.0        NaN
# 15        South Carolina      150891       NaN       3442.0        NaN
# 16              Virginia      150803       NaN       3270.0        NaN
# 17              Michigan      141271       NaN       7124.0        NaN
# 18              Missouri      136462       NaN       2303.0        NaN
# 19         Massachusetts      134303       NaN       9507.0        NaN
# 20             Wisconsin      130798       NaN       1372.0        NaN
# 21              Maryland      126819       NaN       3957.0        NaN
# 22               Indiana      124059       NaN       3669.0        NaN
# 23             Minnesota      102787       NaN       2126.0        NaN
# 24           Mississippi      100167       NaN       3011.0        NaN
# 25            Washington       92088       NaN       2145.0        NaN
# 26                  Iowa       91965       NaN       1378.0        NaN
# 27              Oklahoma       90748       NaN       1051.0        NaN
# 28              Arkansas       86525       NaN       1407.0        NaN
# 29                Nevada       81708       NaN       1620.0        NaN
# 30                  Utah       76225       NaN        476.0        NaN
# 31              Colorado       72555       NaN       2060.0        NaN
# 32              Kentucky       72001       NaN       1205.0        NaN
# 33                Kansas       62310       NaN        698.0        NaN
# 34           Connecticut       58297       NaN       4513.0        NaN
# 35              Nebraska       47403       NaN        497.0        NaN
# 36                 Idaho       43702       NaN        480.0        NaN
# 37                Oregon       34511       NaN        571.0        NaN
# 38            New Mexico       30296       NaN        890.0        NaN
# 39          Rhode Island       25076       NaN       1118.0        NaN
# 40          South Dakota       23986       NaN        248.0        NaN
# 41          North Dakota       23134       NaN        271.0        NaN
# 42              Delaware       21125       NaN        645.0        NaN
# 43         West Virginia       16468       NaN        357.0        NaN
# 44  District Of Columbia       15473       NaN        629.0        NaN
# 45               Montana       14356       NaN        186.0        NaN
# 46                Hawaii       12734       NaN        153.0        NaN
# 47         New Hampshire        8597       NaN        442.0        NaN
# 48                Alaska        8217       NaN         58.0        NaN
# 49               Wyoming        6365       NaN         53.0        NaN
#
#     TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 0        4818509.0    2568060.0           22963.0          647.0  110526283.0
# 1         425001.0     388624.0           21000.0          408.0   14998888.0
# 2         695684.0      90016.0           27665.0          568.0    7020828.0
# 3         354291.0     345660.0           33271.0          682.0    5383648.0
# 4         397523.0      67221.0           25601.0         1711.0   11110291.0
# 5         107459.0     207485.0           30335.0          672.0    3307052.0
# 6         210576.0      83228.0           23898.0          712.0    5834762.0
# 7          35696.0     178998.0           30280.0          784.0    1783985.0
# 8         184422.0      28835.0           20679.0          346.0    3130783.0
# 9         172371.0      22592.0           23780.0         1830.0    3672127.0
# 23       375209.0   5639632.0
# 24       276594.0   2976149.0
# 25       252526.0   7614893.0
# 26       259149.0   3155070.0
# 27       319010.0   3956971.0
# 28       357126.0   3017804.0
# 29       349273.0   3080156.0
# 30       346418.0   3205958.0
# 31       163636.0   5758736.0
# 32       340275.0   4467673.0
# 33       182307.0   2913314.0
# 34       469520.0   3565287.0
# 35       244864.0   1934408.0
# 36       177033.0   1787065.0
# 37       166417.0   4217737.0
# 38       449017.0   2096829.0
# 39       752354.0   1059361.0
# 40       223837.0    884659.0
# 41       322816.0    762062.0
# 42       299201.0    973764.0
# 43       324866.0   1792147.0
# 44       563301.0    705749.0
# 45       331952.0   1068778.0
# 46       305614.0   1415872.0
# 47       228574.0   1359711.0
# 48       646927.0    731545.0
# 49       285511.0    578759.0

# %%
from datetime import date
from datetime import timedelta
today_date = date.today()
yesterday_date = today_date - timedelta(days = 1)
df['Date']= yesterday_date

# %%
df
# Out:
#                  USAState  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0               USA Total     7600846       NaN     214277.0        NaN
# 1              California      829744       NaN      16119.0        NaN
# 2                   Texas      802180       NaN      16480.0        NaN
# 3                 Florida      714591       NaN      14640.0        NaN
# 4                New York      498034       NaN      33290.0        NaN
# ..                    ...         ...       ...          ...        ...
# 59          Navajo Nation       10404       NaN        558.0        NaN
# 60    Grand Princess Ship         103       NaN          3.0        NaN
# 61      Wuhan Repatriated           3       NaN          NaN        NaN
# 62  Diamond Princess Ship          46       NaN          NaN        NaN
# 63                 Total:     7600846       NaN     214277.0        NaN
#
#     TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 0        4818509.0    2568060.0           22963.0          647.0  110526283.0
# 1         425001.0     388624.0           21000.0          408.0   14998888.0
# 2         695684.0      90016.0           27665.0          568.0    7020828.0
# 3         354291.0     345660.0           33271.0          682.0    5383648.0
# 4         397523.0      67221.0           25601.0         1711.0   11110291.0
# ..             ...          ...               ...            ...          ...
# 59             NaN          NaN               NaN            NaN     102753.0
# 60             NaN        100.0               NaN            NaN          NaN
# 61             NaN          3.0               NaN            NaN          3.0
# 62             NaN         46.0               NaN            NaN         46.0
# 63       4818509.0    2568060.0           22963.0          647.0  110526283.0
#
#     Tests/ 1M pop  Population        Date
# 0        333914.0         NaN  2020-10-02
# 1        379601.0  39512223.0  2020-10-02
# 2        242132.0  28995881.0  2020-10-02
# 3        250662.0  21477737.0  2020-10-02
# 4        571119.0  19453561.0  2020-10-02
# ..            ...         ...         ...
# 59            NaN         NaN  2020-10-02
# 60            NaN         NaN  2020-10-02
# 61            NaN         NaN  2020-10-02
# 62            NaN         NaN  2020-10-02
# 63       333914.0         NaN  2020-10-02
#
# [64 rows x 13 columns]

# %%
#pip install pymongo

# %%
import pymongo
print("Setting up mongo client")
client = pymongo.MongoClient("localhost", 27017)
print("Connecting to database ...")
db = client.admin
database_name = db.name
print("Connected Successfully!")
# output DB name
print("The database name is: {}".format(database_name))
# Out:
# Setting up mongo client
# Connecting to database ...
# Connected Successfully!
# The database name is: admin

# %%
df.to_json('/data/db/10032020.json')
