# %%
import requests
URL = "https://www.worldometers.info/coronavirus/country/us/"
page = requests.get(URL)
print(page)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(id = 'usa_table_countries_today')
results (print)
# Out:
# <thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">USA<br>State</br></th>
# <th width="20">Total<br>Cases</br></th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th width="30">Source</th>
# <th width="30">Projections</th>
# </tr>
# </thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">USA<br>State</br></th>
# <th width="20">Total<br>Cases</br></th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# ...

# %%
content = results.find_all('td')
print(content)
# Out:
# [<td></td>, <td style="text-align:left;">USA Total</td>, <td>6,706,522</td>, <td>+29,921</td>, <td>198,474</td>, <td>+346</td>, <td>3,968,885</td>, <td>2,539,163</td>, <td>20,261</td>, <td>600</td>, <td>92,335,239</td>, <td>278,956</td>, <td></td>, <td> </td>, <td> </td>, <td style="font-size:12px;color: grey;text-align:center;vertical-align:middle;">1</td>, <td style="font-weight: bold; font-size:15px; text-align:left;">
# <a class="mt_a" href="/coronavirus/usa/california/">California</a> </td>, <td style="font-weight: bold; text-align:right">760,704 </td>, <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;">
# +1,520 </td>, <td style="font-weight: bold; text-align:right;">
# 14,371  </td>, <td style="font-weight: bold; text-align:right;background-color:red; color:white">+38 </td>, <td style="font-weight: bold; text-align:right;">
# 372,810 </td>, <td style="text-align:right;font-weight:bold;">
# ...

# %%
for entries in content[15:]:
    print(entries.text.strip())
# Out:
# 1
# California
# 760,704
# +1,520
# 14,371
# +38
# 372,810
# 373,523
# 19,252
# 364
# 12,690,016
# 321,167
# 39,512,223
# [view by county] [1]
# [projections]
# 2
# Texas
# 691,316
# +2,268
# 14,489
# +39
# 593,733
# 83,094
# 23,842
# 500
# 5,989,638
# 206,569
# 28,995,881
# [view by county] [1] [2]
# [projections]
# 3
# Florida
# 663,994
# +2,423
# 12,614
# +10
# 148,125
# 503,255
# 30,915
# 587
# 4,930,974
# 229,585
# 21,477,737
# [view by county] [1] [2] [3]
# [projections]
# 4
# New York
# 477,595
# +705
# 33,116
#
# 381,899
# 62,580
# 24,551
# 1,702
# 9,318,293
# 479,002
# 19,453,561
# [view by county] [1] [2] [3]
# [projections]
# 5
# Georgia
# 294,314
# +1,409
# 6,333
# +46
# 59,044
# 228,937
# 27,720
# 596
# 2,891,996
# 272,382
# 10,617,423
# [1]
# [projections]
# 6
# Illinois
# 263,466
# +1,462
# 8,541
# +14
# 199,416
# 55,509
# 20,791
# 674
# 4,735,866
# 373,732
# 12,671,821
# [1] [2] [3] [4]
# [projections]
# 7
# Arizona
# 208,512
# +384
# 5,322
# +7
# 32,628
# 170,562
# ...

# %%
Number =[]
State =[]
TotalCases=[]
NewCases=[]
TotalDeaths=[]
NewDeaths=[]
TotalRecovered=[]
ActiveCases=[]
TotalCasesPerPop=[]
DeathsPerPop=[]
TotalTests=[]
TestsPerPop=[]
Population=[]

# %%
i=1;
iopub_data_rate_limit=10000000
for entry in content:
    if i%15 == 1:
        Number.append(entry.text.strip())
        print(Number)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
